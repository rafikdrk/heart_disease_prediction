# %% [markdown]
# # Heart failure prediction

# %%
# load packages
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mutual_info_score, mean_squared_error, accuracy_score, recall_score, f1_score, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import OneHotEncoder, QuantileTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

import pickle 
from xgboost import XGBClassifier

# %%
# import the data
data = pd.read_csv('heart.csv')
data
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up             0
# 1     49   F           NAP  ...      1.0      Flat             1
# 2     37   M           ATA  ...      0.0        Up             0
# 3     48   F           ASY  ...      1.5      Flat             1
# 4     54   M           NAP  ...      0.0        Up             0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat             1
# 914   68   M           ASY  ...      3.4      Flat             1
# 915   57   M           ASY  ...      1.2      Flat             1
# 916   57   F           ATA  ...      0.0      Flat             1
# 917   38   M           NAP  ...      0.0        Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## pre-processing

# %%
data.columns=[column.lower().replace(' ','_') for column in data.columns]

# %% [markdown]
# ## EDA

# %%
data.head()
# Out:
#    age sex chestpaintype  ...  oldpeak  st_slope  heartdisease
# 0   40   M           ATA  ...      0.0        Up             0
# 1   49   F           NAP  ...      1.0      Flat             1
# 2   37   M           ATA  ...      0.0        Up             0
# 3   48   F           ASY  ...      1.5      Flat             1
# 4   54   M           NAP  ...      0.0        Up             0
#
# [5 rows x 12 columns]

# %%
data.shape
# Out:
# (918, 12)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'chestpaintype', 'restingbp', 'cholesterol', 'fastingbs',
#        'restingecg', 'maxhr', 'exerciseangina', 'oldpeak', 'st_slope',
#        'heartdisease'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             918 non-null    int64
#  1   sex             918 non-null    object
#  2   chestpaintype   918 non-null    object
#  3   restingbp       918 non-null    int64
#  4   cholesterol     918 non-null    int64
#  5   fastingbs       918 non-null    int64
#  6   restingecg      918 non-null    object
#  7   maxhr           918 non-null    int64
#  8   exerciseangina  918 non-null    object
#  9   oldpeak         918 non-null    float64
#  10  st_slope        918 non-null    object
#  11  heartdisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.describe().T
# Out:
#               count        mean         std   min     25%    50%    75%    max
# age           918.0   53.510893    9.432617  28.0   47.00   54.0   60.0   77.0
# restingbp     918.0  132.396514   18.514154   0.0  120.00  130.0  140.0  200.0
# cholesterol   918.0  198.799564  109.384145   0.0  173.25  223.0  267.0  603.0
# fastingbs     918.0    0.233115    0.423046   0.0    0.00    0.0    0.0    1.0
# maxhr         918.0  136.809368   25.460334  60.0  120.00  138.0  156.0  202.0
# oldpeak       918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5    6.2
# heartdisease  918.0    0.553377    0.497414   0.0    0.00    1.0    1.0    1.0

# %%
data.dtypes
# Out:
# age                 int64
# sex                object
# chestpaintype      object
# restingbp           int64
# cholesterol         int64
# fastingbs           int64
# restingecg         object
# maxhr               int64
# exerciseangina     object
# oldpeak           float64
# st_slope           object
# heartdisease        int64
# dtype: object

# %%
data.nunique()
# Out:
# age                50
# sex                 2
# chestpaintype       4
# restingbp          67
# cholesterol       222
# fastingbs           2
# restingecg          3
# maxhr             119
# exerciseangina      2
# oldpeak            53
# st_slope            3
# heartdisease        2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age               0
# sex               0
# chestpaintype     0
# restingbp         0
# cholesterol       0
# fastingbs         0
# restingecg        0
# maxhr             0
# exerciseangina    0
# oldpeak           0
# st_slope          0
# heartdisease      0
# dtype: int64

# %% [markdown]
#  we have no NAN in our data

# %% [markdown]
# ## Data Visualization

# %%
data['heartdisease'].value_counts()
# Out:
# heartdisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
sns.countplot(x='heartdisease', data=data)
# Out:
# <Axes: xlabel='heartdisease', ylabel='count'>

# %%
# Group by Sex and 'HeartDisease' and calculate counts
gender_heart_disease_counts = data.groupby(
    ['sex', 'heartdisease']).size().unstack()
gender_heart_disease_counts
# Out:
# heartdisease    0    1
# sex
# F             143   50
# M             267  458

# %% [markdown]
# the majority of the patients are males by 458 patient

# %%
# Visualization all dataset by heartdisease.
for col in data.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(data=data, x=data[col],hue="heartdisease" ,multiple="dodge")

    plt.show()

# %%
# age vs max heart rate (maxhr)

plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='age', y='maxhr', hue='heartdisease', palette='Set1')
plt.title('Age vs Maximum Heart Rate')
plt.xlabel('Age (years)')
plt.ylabel('Maximum Heart Rate')
# Out:
# Text(0, 0.5, 'Maximum Heart Rate')

# %%
sns.lineplot(data=data, x='age', y='maxhr', hue='heartdisease', palette=['lightblue', 'lightcoral'])
plt.title('Age vs. Maximum Heart Rate')
plt.xlabel('Age (years)')
plt.ylabel('Maximum Heart Rate Achieved')
# plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# As it shown above, those who are aged have less max heart rate achieved.
# And who has less maxhr are most likely have heartdisease.

# %%
# age vs cholesterol

plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='age', y='cholesterol', hue='heartdisease', palette=['lightblue', 'lightcoral'])
plt.title('Age vs Cholesterol')
plt.xlabel('Age')
plt.ylabel('Cholesterol (mm/dl)')
# Out:
# Text(0, 0.5, 'Cholesterol (mm/dl)')

# %%
datap=data[data["heartdisease"]==1]
sns.displot(data=data,y='cholesterol',x='age', hue='heartdisease',palette='mako',cmap='coolwarm');
# Out:
# C:\Users\ce pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# We can see those with age around 60 years are the most affected to Heart Disease. And Age doesnt affect our data on Cholesterol levels much.

# %% [markdown]
# ## Modeling
#
# ### split the data

# %%
train,test=train_test_split(data,random_state=123,test_size=.2)
# Define the target variable
y_train = train['heartdisease'].values
y_test = test['heartdisease'].values

# Remove the 'heartdisease' column from the feature sets
x_train = train
x_test = test
del x_train['heartdisease']
del x_test['heartdisease']

# %%
dv=DictVectorizer(sparse=False)
x_train=x_train.to_dict(orient='records')
x_test=x_test.to_dict(orient='records')

x_train=dv.fit_transform(x_train)
x_test=dv.transform(x_test)

# %% [markdown]
# ### logistic regression

# %%
# Create a Logistic Regression model
lr = LogisticRegression(C=1,max_iter=2000)

# Fit the model to the training data
lr.fit(x_train, y_train)

# Make predictions on the test data
y_pred = lr.predict(x_test)

# %%
# Evaluate the model
lr.score(x_train,y_train)
# Out:
# 0.8760217983651226

# %%
lr.score(x_test,y_test)
# Out:
# 0.8478260869565217

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8478260869565217

# %% [markdown]
# ### AdaBoost

# %%
# Create a AdaBoost model
ada = AdaBoostClassifier(n_estimators=6,learning_rate=0.3)
ada.fit(x_train, y_train)
y_pred = ada.predict(x_test)

# %%
# Evaluate the model
# train accuracy
ada.score(x_train,y_train)
# Out:
# 0.8610354223433242

# %%
# test accuracy
ada.score(x_test,y_test)
# Out:
# 0.8369565217391305

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8369565217391305

# %% [markdown]
# ### XGBoost

# %%
xgb = XGBClassifier(n_estimators=10,max_depth=5, learning_rate=0.2)
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)

# %%
xgb.score(x_train,y_train)
# Out:
# 0.9386920980926431

# %%
xgb.score(x_test,y_test)
# Out:
# 0.8586956521739131

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8586956521739131

# %% [markdown]
# ### Random forest

# %%
rf=RandomForestClassifier(max_depth=15,n_estimators=12)
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

# %%
rf.score(x_train,y_train)
# Out:
# 0.9918256130790191

# %%
rf.score(x_test,y_test)
# Out:
# 0.8478260869565217

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8478260869565217

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test)
# Out:
# 0.8043478260869565

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8043478260869565

# %% [markdown]
# It looks like that the best model based on the accuracy is XGBoost by 85.5% accuracy

# %% [markdown]
# ### Best model

# %%
xgb = XGBClassifier(n_estimators=10,max_depth=5, learning_rate=0.2)
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
mean_absolute_error(y_test, y_pred)
# Out:
# Accuracy: 0.8586956521739131
# 0.14130434782608695

# %% [markdown]
# ### saving the model
# using the pickle to deciralize the model and the dictvectorizer

# %%
with open("model.bin","wb") as file :
    pickle.dump(xgb,file)
    
with open("dv.bin","wb") as dvv :
    pickle.dump(dv,dvv)
